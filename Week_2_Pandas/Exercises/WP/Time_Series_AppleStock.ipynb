# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
pd.read_csv(r'C:\Users\ADMIN\Desktop\ZINDUA\PYDATA\Week_2_Pandas\Exercises\WP\appl_1980_2014.csv')
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple = pd.read_csv(r'C:\Users\ADMIN\Desktop\ZINDUA\PYDATA\Week_2_Pandas\Exercises\WP\appl_1980_2014.csv')

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple["Date"] = pd.to_datetime(apple["Date"])
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple = apple.set_index("Date")
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.index.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple = apple.sort_index()
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
last_business_day = apple.resample("BM").last()
last_business_day.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10528\3172840996.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   last_business_day = apple.resample("BM").last()
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 1980-12-31  34.25  34.25  34.13  34.13   8937600       0.53
# 1981-01-30  28.50  28.50  28.25  28.25  11547200       0.44
# 1981-02-27  26.50  26.75  26.50  26.50   3690400       0.41
# 1981-03-31  24.75  24.75  24.50  24.50   3998400       0.38
# 1981-04-30  28.38  28.62  28.38  28.38   3152800       0.44

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
(apple.index[-1] - apple.index[0]).days
# Out:
# 12261

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple.index.to_period("M").nunique()
# Out:
# 404

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
apple["Adj Close"].plot(figsize=(13.5, 9))
plt.title("Apple Adjusted Close Price (1980–2014)")
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
